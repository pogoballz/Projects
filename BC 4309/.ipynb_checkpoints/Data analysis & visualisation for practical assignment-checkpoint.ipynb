# %%
#!pip install matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset= pd.read_csv("listings (1).csv")

# %%
plt.figure(figsize=(10,5))
sns.countplot(dataset["neighbourhood_group"])

# %%
dataset.head()
df = pd.DataFrame(dataset)
dada = dataset.fillna('0')
#col = df['neighbourhood_group']
#plt.hist(dataset['price'],bins=20,range= (0,500))

# %%
#plt.hist(dataset['price'],range=(1000,2000),facecolor='green',edgecolor='black')

# %%
neighbour = pd.read_csv('neighbourhood.csv')
count = dada['row labels'][:43]
neigh = dada['Count of neighbourhood'][:43]
# print(dada)

plt.bar(count, neigh)
# Out:
# 0                  Ang Mo Kio
# 1                       Bedok
# 2                      Bishan
# 3                 Bukit Batok
# 4                 Bukit Merah
# 5               Bukit Panjang
# 6                 Bukit Timah
# 7     Central Water Catchment
# 8               Choa Chu Kang
# 9                    Clementi
# 10              Downtown Core
# 11                    Geylang
# 12                    Hougang
# 13                Jurong East
# 14                Jurong West
# 15                    Kallang
# 16               Lim Chu Kang
# 17                     Mandai
# 18               Marina South
# 19              Marine Parade
# 20                     Museum
# 21                     Newton
# 22                     Novena
# 23                    Orchard
# 24                     Outram
# 25                  Pasir Ris
# 26                    Punggol
# 27                 Queenstown
# 28               River Valley
# 29                     Rochor
# 30                  Sembawang
# ...

# %%
import seaborn as sns

df1 = dataset.copy()
lat = dataset['latitude']
long = dataset['longitude']
price = dataset['price']
#df1['latitude'] = [i.latitude for i in lat]

# %%
df = dataset[(dataset['price'] >= 1000) & (dataset['price'] <= 10000)]
lat = df['latitude']
long = df['longitude']
# price = dataset[(dataset['price'] >= 99) & (dataset['price'] <= 200)]
price = df['price']
fig,ax = plt.subplots()
numbers = 10000
bins= 100
points = ax.scatter(lat,long,c=price,cmap = "magma")
plt.colorbar(points)
plt.xlabel('latitude')
plt.ylabel('longitude')
# Out:
# Text(0, 0.5, 'longitude')

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df.longitude,df.latitude,hue=df.neighbourhood_group)
plt.ioff()
